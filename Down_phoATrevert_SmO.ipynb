# %%
import plotly
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
from IPython.display import Image 
#im2 = Image(filename ="Legend2.png")

import pandas as pd
import numpy as np
import plotly.graph_objects as go



df = pd.read_csv (r'Interactive2_2500v2501.csv') 

adjpval = df['adjpval']
Name = df['Name']
avgexp = df['avgexp']
logfc = df['logfc']
pointsize = df['pointsize']

#opaq = df['Original Opaq']
#hovinfo = df['Original Hovinfo']
#pointcolor = df['Original Color']

#opaq = df['UpOpaq_2500vTn1phoAT']
#hovinfo = df['UpHovinfo_2500vTn1phoAT']
#pointcolor = df['UpColor_2500vTn1phoAT']

#opaq = df['UpOpaq_2500vTn1phoATcomp']
#hovinfo = df['UpHovinfo_2500vTn1phoATcomp']
#pointcolor = df['UpColor_2500vTn1phoATcomp']

opaq = df['UpOpaq_2500vTn1phoATrevert']
hovinfo = df['UpHovinfo_2500vTn1phoATrevert']
pointcolor = df['UpColor_2500vTn1phoATrevert']

#opaq = df['UpOpaq_2500vTn15']
#hovinfo = df['UpHovinfo_2500vTn15']
#pointcolor = df['UpColor_2500vTn15']

#opaq = df['UpOpaq_2500vTn17lppzplppz']
#hovinfo = df['UpHovinfo_2500vTn17lppzplppz']
#pointcolor = df['UpColor_2500vTn17lppzplppz']

#opaq = df['UpOpaq_2500vTn17lppz']
#hovinfo = df['UpHovinfo_2500vTn17lppz']
#pointcolor = df['UpColor_2500vTn17lppz']

#opaq = df['UpOpaq_2500vTn19pykppyk']
#hovinfo = df['UpHovinfo_2500vTn19pykppyk']
#pointcolor = df['UpColor_2500vTn19pykppyk']

#opaq = df['UpOpaq_2500vTn19pyk']
#hovinfo = df['UpHovinfo_2500vTn19pyk']
#pointcolor = df['UpColor_2500vTn19pyk']

#opaq = df['DownOpaq_2500vTn1phoAT']
#hovinfo = df['DownHovinfo_2500vTn1phoAT']
#pointcolor = df['DownColor_2500vTn1phoAT']

#opaq = df['DownOpaq_2500vTn1phoATcomp']
#hovinfo = df['DownHovinfo_2500vTn1phoATcomp']
#pointcolor = df['DownColor_2500vTn1phoATcomp']

#opaq = df['DownOpaq_2500vTn1phoATrevert']
#hovinfo = df['DownHovinfo_2500vTn1phoATrevert']
#pointcolor = df['DownColor_2500vTn1phoATrevert']

#opaq = df['DownOpaq_2500vTn15']
#hovinfo = df['DownHovinfo_2500vTn15']
#pointcolor = df['DownColor_2500vTn15']

#opaq = df['DownOpaq_2500vTn17lppzplppz']
#hovinfo = df['DownHovinfo_2500vTn17lppzplppz']
#pointcolor = df['DownColor_2500vTn17lppzplppz']

#opaq = df['DownOpaq_2500vTn19pykppyk']
#hovinfo = df['DownHovinfo_2500vTn19pykppyk']
#pointcolor = df['DownColor_2500vTn19pykppyk']

#opaq = df['DownOpaq_2500vTn19pyk']
#hovinfo = df['DownHovinfo_2500vTn19pyk']
#pointcolor = df['DownColor_2500vTn19pyk']







x=-1*logfc
y=-1*np.log10(adjpval)

# Build figure
fig = go.Figure()

fig.add_trace(
    go.Scatter(
        mode='markers',
        x=x,
        y=y,
        text = Name.to_list(),
   
        hoverinfo=hovinfo.to_list(),
        
        marker=dict(
            color=pointcolor,
            size=pointsize*0.75,
            opacity=opaq,
            line=dict(
                color='black',
                width=0.15
            )
            
        ),
        showlegend=False
        
    )
)



fig.update_layout(
    title={
        'text': "Tn1 phoAT Revert SmO (Upregulated compared to 2500)",
        'y':0.85,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'},
    yaxis_title="-log10(Adjusted P value)",
    xaxis_title="Log2 Fold Change")



fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="e4acecbd-df8e-4ee2-860d-166e3bf4317b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e4acecbd-df8e-4ee2-860d-166e3bf4317b")) {
#                     Plotly.newPlot(
# ...

# %%
from IPython.display import HTML
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>
